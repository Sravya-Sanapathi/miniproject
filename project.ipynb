# %%
import pandas as pd
filePath = 'C:\\Users\\Admin\\Desktop\\Problem Solving\\Match.csv'
def readCsvData(filePath):
    return pd.read_csv(filePath)
df = readCsvData(filePath)
print(df)
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
df['Season_Year'].groupby(df.Season_Year).agg('count')
# Out:
# Season_Year
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    60
# Name: Season_Year, dtype: int64

# %%
df['match_winner'].groupby(df.match_winner).agg('count')
# Out:
# match_winner
# Chennai Super Kings            79
# Deccan Chargers                29
# Delhi Daredevils               62
# Gujarat Lions                  13
# Kings XI Punjab                70
# Kochi Tuskers Kerala            6
# Kolkata Knight Riders          77
# Mumbai Indians                 91
# Pune Warriors                  12
# Rajasthan Royals               63
# Rising Pune Supergiants        15
# Royal Challengers Bangalore    73
# Sunrisers Hyderabad            42
# abandoned                       1
# tied                            1
# Name: match_winner, dtype: int64

# %%
t = df[df['Season_Year'] == 2011]['Season_Year'].groupby(df['match_winner']).count()
t
# Out:
# match_winner
# Chennai Super Kings            11
# Deccan Chargers                 6
# Delhi Daredevils                4
# Kings XI Punjab                 7
# Kochi Tuskers Kerala            6
# Kolkata Knight Riders           8
# Mumbai Indians                 10
# Pune Warriors                   4
# Rajasthan Royals                6
# Royal Challengers Bangalore    10
# Name: Season_Year, dtype: int64

# %%
t.index.tolist()
t.values.tolist()
# Out:
# [11, 6, 4, 7, 6, 8, 10, 4, 6, 10]

# %%
values = t.values.tolist()
divisions = t.index.tolist()
index = np.arange(len(divisions))

plt.barh(divisions,marks,color="purple")
plt.show()

# %%
city =df.groupby('City_Name')
p=city.get_group('Hyderabad')
player=p.groupby('ManOfMach')['City_Name'].count()
print(player)
# Out:
# ManOfMach
# A Mishra             2
# AB Dinda             1
# AT Rayudu            1
# B Kumar              1
# CH Morris            1
# DA Warner            6
# DJ Bravo             1
# DJG Sammy            1
# DW Steyn             3
# G Gambhir            1
# GH Vihari            2
# I Sharma             1
# MJ McClenaghan       1
# MR Marsh             1
# Mandeep Singh        1
# Mustafizur Rahman    1
# PA Patel             1
# PC Valthaty          1
# R Vinay Kumar        1
# SC Ganguly           1
# SE Marsh             1
# SK Raina             2
# SK Trivedi           1
# SL Malinga           1
# UT Yadav             1
# V Kohli              1
# V Sehwag             2
# WP Saha              1
# YK Pathan            2
# Name: City_Name, dtype: int64
